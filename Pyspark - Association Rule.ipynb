# %% [markdown]
# ## Pyspark - Association Rule

# %%
from pyspark.ml.fpm import FPGrowth

df = spark.createDataFrame([
    (0, [1, 2, 5]),
    (1, [1, 2, 3, 5]),
    (2, [1, 2])
], ["id", "items"])

fpGrowth = FPGrowth(itemsCol="items", minSupport=0.5, minConfidence=0.6)
model = fpGrowth.fit(df)

# Display frequent itemsets.
model.freqItemsets.show()

# Display generated association rules.
model.associationRules.show()

# transform examines the input items against all the association rules and summarize the
# consequents as prediction
model.transform(df).show()
# Out:
# +---------+----+
# |    items|freq|
# +---------+----+
# |      [1]|   3|
# |      [2]|   3|
# |   [2, 1]|   3|
# |      [5]|   2|
# |   [5, 2]|   2|
# |[5, 2, 1]|   2|
# |   [5, 1]|   2|
# +---------+----+
#
# +----------+----------+------------------+----+------------------+
# |antecedent|consequent|        confidence|lift|           support|
# +----------+----------+------------------+----+------------------+
# |       [5]|       [2]|               1.0| 1.0|0.6666666666666666|
# |       [5]|       [1]|               1.0| 1.0|0.6666666666666666|
# |    [5, 1]|       [2]|               1.0| 1.0|0.6666666666666666|
# |    [5, 2]|       [1]|               1.0| 1.0|0.6666666666666666|
# |       [2]|       [1]|               1.0| 1.0|               1.0|
# |       [2]|       [5]|0.6666666666666666| 1.0|0.6666666666666666|
# |    [2, 1]|       [5]|0.6666666666666666| 1.0|0.6666666666666666|
# |       [1]|       [2]|               1.0| 1.0|               1.0|
# |       [1]|       [5]|0.6666666666666666| 1.0|0.6666666666666666|
# +----------+----------+------------------+----+------------------+
#
# +---+------------+----------+
# | id|       items|prediction|
# +---+------------+----------+
# |  0|   [1, 2, 5]|        []|
# |  1|[1, 2, 3, 5]|        []|
# |  2|      [1, 2]|       [5]|
# +---+------------+----------+

# %%
df = spark.createDataFrame([
    (0, ['apple', 'orange','eggs','milk']),
    (1, ['apple', 'orange','bread','milk']),
    (2, ['apple', 'orange']),
    (3, ['apple', 'bread']),
    (4, ['eggs','milk','bread']),
    (5, ['orange', 'tomato','apple']),
    (6, ['eggs','bread','milk','mushrooms','tomato']),
    (7, ['bread','milk','mushrooms','tomato']),
    (8, ['bread','milk']),
    (9, ['apple','orange','mushroom','tomato']),
    (10,['bread','milk','mushrooms','apple']),
    (11, ['apple', 'orange','eggs','milk','bread']), 
    (12, ['bread','milk','mushrooms']),
    (13, ['apple', 'orange','bread']),
    (14, ['eggs','mushrooms','tomato']),
    (15, ['mushrooms','tomato']),
    (16, ['milk', 'orange','apple']),
    (17, ['mushrooms','tomato']),
    (18, ['tomato', 'apple','orange']),
    (19, ['eggs','tomato']),
    (20, ['bread','apple'])
    
    
], ["id", "items"])

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>items</th></tr></thead><tbody><tr><td>0</td><td>List(apple, orange, eggs, milk)</td></tr><tr><td>1</td><td>List(apple, orange, bread, milk)</td></tr><tr><td>2</td><td>List(apple, orange)</td></tr><tr><td>3</td><td>List(apple, bread)</td></tr><tr><td>4</td><td>List(eggs, milk, bread)</td></tr><tr><td>5</td><td>List(orange, tomato, apple)</td></tr><tr><td>6</td><td>List(eggs, bread, milk, mushrooms, tomato)</td></tr><tr><td>7</td><td>List(bread, milk, mushrooms, tomato)</td></tr><tr><td>8</td><td>List(bread, milk)</td></tr><tr><td>9</td><td>List(apple, orange, mushroom, tomato)</td></tr><tr><td>10</td><td>List(bread, milk, mushrooms, apple)</td></tr><tr><td>11</td><td>List(apple, orange, eggs, milk, bread)</td></tr><tr><td>12</td><td>List(bread, milk, mushrooms)</td></tr><tr><td>13</td><td>List(apple, orange, bread)</td></tr><tr><td>14</td><td>List(eggs, mushrooms, tomato)</td></tr><tr><td>15</td><td>List(mushrooms, tomato)</td></tr><tr><td>16</td><td>List(milk, orange, apple)</td></tr><tr><td>17</td><td>List(mushrooms, tomato)</td></tr><tr><td>18</td><td>List(tomato, apple, orange)</td></tr><tr><td>19</td><td>List(eggs, tomato)</td></tr><tr><td>20</td><td>List(bread, apple)</td></tr></tbody></table></div>

# %%
#### 1.4
fpGrowth = FPGrowth(itemsCol="items", minSupport=0.2, minConfidence=0.3)
model = fpGrowth.fit(df)

# %%
# 1.5
model.freqItemsets.show()
# Out:
# +-------------------+----+
# |              items|freq|
# +-------------------+----+
# |            [apple]|  12|
# |            [bread]|  11|
# |     [bread, apple]|   6|
# |             [milk]|  10|
# |      [milk, bread]|   8|
# |      [milk, apple]|   5|
# |           [tomato]|   9|
# |           [orange]|   9|
# |    [orange, apple]|   9|
# |        [mushrooms]|   7|
# |[mushrooms, tomato]|   5|
# |             [eggs]|   6|
# +-------------------+----+

# %%
# 1.6
model.associationRules.show()
# Out:
# +-----------+-----------+------------------+------------------+-------------------+
# | antecedent| consequent|        confidence|              lift|            support|
# +-----------+-----------+------------------+------------------+-------------------+
# |     [milk]|    [bread]|               0.8|1.5272727272727273|0.38095238095238093|
# |     [milk]|    [apple]|               0.5|             0.875|0.23809523809523808|
# |[mushrooms]|   [tomato]|0.7142857142857143|1.6666666666666667|0.23809523809523808|
# |   [tomato]|[mushrooms]|0.5555555555555556|1.6666666666666667|0.23809523809523808|
# |    [apple]|    [bread]|               0.5|0.9545454545454545| 0.2857142857142857|
# |    [apple]|     [milk]|0.4166666666666667|0.8750000000000001|0.23809523809523808|
# |    [apple]|   [orange]|              0.75|              1.75|0.42857142857142855|
# |    [bread]|    [apple]|0.5454545454545454|0.9545454545454545| 0.2857142857142857|
# |    [bread]|     [milk]|0.7272727272727273|1.5272727272727273|0.38095238095238093|
# |   [orange]|    [apple]|               1.0|              1.75|0.42857142857142855|
# +-----------+-----------+------------------+------------------+-------------------+

# %%
# 1.7
dfTest = spark.createDataFrame([
   
    (0, ['apple','bread','milk']),
    (1, ['bread']),
    (2, ['orange','milk']),
    (3, ['bread','mushrooms','milk']),
    (4, ['apple']),
    (5, ['orange','bread']),
    (6, ['mushrooms','bread'])
            
], ["id", "items"])
display(dfTest)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>items</th></tr></thead><tbody><tr><td>0</td><td>List(apple, bread, milk)</td></tr><tr><td>1</td><td>List(bread)</td></tr><tr><td>2</td><td>List(orange, milk)</td></tr><tr><td>3</td><td>List(bread, mushrooms, milk)</td></tr><tr><td>4</td><td>List(apple)</td></tr><tr><td>5</td><td>List(orange, bread)</td></tr><tr><td>6</td><td>List(mushrooms, bread)</td></tr></tbody></table></div>

# %%
#  1.8
model.transform(dfTest).show()
# Out:
# +---+--------------------+--------------------+
# | id|               items|          prediction|
# +---+--------------------+--------------------+
# |  0|[apple, bread, milk]|            [orange]|
# |  1|             [bread]|       [apple, milk]|
# |  2|      [orange, milk]|      [bread, apple]|
# |  3|[bread, mushrooms...|     [apple, tomato]|
# |  4|             [apple]|[bread, milk, ora...|
# |  5|     [orange, bread]|       [apple, milk]|
# |  6|  [mushrooms, bread]|[tomato, apple, m...|
# +---+--------------------+--------------------+

# %% [markdown]
# 1.9<br>
# Resources: <br>
# 1) Dr. Liao’s tutorials, code snippets, and programming hints in the lab
# 2) https://spark.apache.org/docs/latest/ml-frequent-pattern-mining.html

# %%
# 1.10
df1 = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/vrajuech@gmu.edu/groceries-2.csv")
df1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>items</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th><th>_c7</th><th>_c8</th><th>_c9</th><th>_c10</th><th>_c11</th><th>_c12</th><th>_c13</th><th>_c14</th><th>_c15</th><th>_c16</th><th>_c17</th><th>_c18</th><th>_c19</th><th>_c20</th><th>_c21</th><th>_c22</th><th>_c23</th><th>_c24</th><th>_c25</th><th>_c26</th><th>_c27</th><th>_c28</th><th>_c29</th><th>_c30</th><th>_c31</th></tr></thead><tbody><tr><td>citrus fruit</td><td>semi-finished bread</td><td>margarine</td><td>ready soups</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>tropical fruit</td><td>yogurt</td><td>coffee</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>whole milk</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>pip fruit</td><td>yogurt</td><td>cream cheese</td><td>meat spreads</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>other vegetables</td><td>whole milk</td><td>condensed milk</td><td>long life bakery product</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>whole milk</td><td>butter</td><td>yogurt</td><td>rice</td><td>abrasive cleaner</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>rolls/buns</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>other vegetables</td><td>UHT-milk</td><td>rolls/buns</td><td>bottled beer</td><td>liquor (appetizer)</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>nul ...

# %%
from pyspark.sql.functions import col, concat_ws
df2n = df1.withColumn('item', concat_ws(',', col('items'), col('_c1'),col('_c2'),col('_c3')))

# %%
df3=df2n.drop('items','_c1','_c2','_c3')

# %%
for field in df3.schema.fields:
    print(field.name +" , "+str(field.dataType))
# Out:
# _c4 , StringType()
# _c5 , StringType()
# _c6 , StringType()
# _c7 , StringType()
# _c8 , StringType()
# _c9 , StringType()
# _c10 , StringType()
# _c11 , StringType()
# _c12 , StringType()
# _c13 , StringType()
# _c14 , StringType()
# _c15 , StringType()
# _c16 , StringType()
# _c17 , StringType()
# _c18 , StringType()
# _c19 , StringType()
# _c20 , StringType()
# _c21 , StringType()
# _c22 , StringType()
# _c23 , StringType()
# _c24 , StringType()
# _c25 , StringType()
# _c26 , StringType()
# _c27 , StringType()
# _c28 , StringType()
# _c29 , StringType()
# _c30 , StringType()
# _c31 , StringType()
# item , StringType()

# %%
from pyspark.sql.functions import split, col
df4 = df3.select(split(col("item"),",").alias("itemsList")) \
    .drop("items")
df4.printSchema()
df4.display()
# Out:
# root
#  |-- itemsList: array (nullable = false)
#  |    |-- element: string (containsNull = false)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>itemsList</th></tr></thead><tbody><tr><td>List(citrus fruit, semi-finished bread, margarine, ready soups)</td></tr><tr><td>List(tropical fruit, yogurt, coffee)</td></tr><tr><td>List(whole milk)</td></tr><tr><td>List(pip fruit, yogurt, cream cheese, meat spreads)</td></tr><tr><td>List(other vegetables, whole milk, condensed milk, long life bakery product)</td></tr><tr><td>List(whole milk, butter, yogurt, rice)</td></tr><tr><td>List(rolls/buns)</td></tr><tr><td>List(other vegetables, UHT-milk, rolls/buns, bottled beer)</td></tr><tr><td>List(pot plants)</td></tr><tr><td>List(whole milk, cereals)</td></tr><tr><td>List(tropical fruit, other vegetables, white bread, bottled water)</td></tr><tr><td>List(citrus fruit, tropical fruit, whole milk, butter)</td></tr><tr><td>List(beef)</td></tr><tr><td>List(frankfurter, rolls/buns, soda)</td></tr><tr><td>List(chicken, tropical fruit)</td></tr><tr><td>List(butter, sugar, fruit/vegetable juice, newspapers)</td></tr><tr><td>List(fruit/vegetable juice)</td></tr><tr><td>List(packaged fruit/vegetables)</td></tr><tr><td>List(chocolate)</td></tr><tr><td>List(specialty bar)</td></tr><tr><td>List(other vegetables)</td></tr><tr><td>List(butter milk, pastry)</td></tr><tr><td>List(whole milk)</td></tr><tr><td>List(tropical fruit, cream cheese, processed cheese, detergent)</td></tr><tr><td>List(tropical fruit, root vegetables, other vegetables, frozen dessert)</td></tr><tr><td>List(bottled water, canned beer)</td></tr><tr><td>List(yogurt)</td></tr><tr><td>List(sausage, rolls/buns, soda, chocolate)</td></tr><tr><td>List(other vegetables)</td></tr><tr><td>List(brown bread, soda, fruit/vegetable juice, canned beer)</td></tr><tr><td>List(yogurt, beverages, bottled water, specialty bar)</td></tr><tr><td>List(hamburger meat, other vegetables, rolls/buns, spices)</td></tr><tr><td>List(root vegetables, other vegetables, whole milk, beverages)</td></tr><tr><td>List(pork, berries, other vegetables, whole milk)</td></tr><tr><td>List(beef, grapes, detergent)</td></tr><tr><td>List(pastry, soda)</td></tr><tr><td>List(fruit/vegetable juice)</td></tr><tr><td>List(canned beer)</td></tr><tr><td>List(root vegetables, other vegetables, whole milk, dessert)</td></tr><tr><td>List(citrus fruit, zwieback, newspapers)</td></tr><tr><td>List(sausage, rolls/buns, soda, canned beer)</td></tr><tr><td>List(tropical fruit, root vegetables, whole milk, yogurt)</td></tr><tr><td>List(berries, yogurt)</td></tr><tr><td>List(canned beer)</td></tr><tr><td>List(butter milk, yogurt, cream cheese, spread cheese)</td></tr><tr><td>List(coffee)</td></tr><tr><td>List(pastry, bottled water)</td></tr><tr><td>List(rolls/buns)</td></tr><tr><td>List(misc. beverages)</td></tr><tr><td>List(root vegetables, other vegetables, butter, curd)</td></tr><tr><td>List(sausage, rolls/buns, cat food, newspapers)</td></tr><tr><td>List(canned beer)</td></tr><tr><td>List(ham, grapes, other vegetables, whole milk)</td></tr><tr><td>List(turkey, tropical fruit, other vegetables, curd)</td></tr><tr><td>List(whole milk, yogurt, processed cheese, pickled vegetables)</td></tr><tr><td>List(whole milk, curd, yogurt, pastry)</td></tr><tr><td>List(packaged fruit/vegetables, brown bread, canned beer)</td></tr><tr><td>List(rolls/buns, oil, bottled water, chewing gum)</td></tr><tr><td>List(ham, beef, whipped/sour cream, ice cream)</td></tr><tr><td>List(rolls/buns, pastry, sugar)</td></tr><tr><td>List(other vegetables, whole milk, frozen vegetables, canned fish)</td></tr><tr><td>List(sausage, pastry)</td></tr><tr><td>List(sausage, beef, whole milk)</td></tr><tr><td>List(frankfurter, tropical fruit, rolls/buns, brown bread)</td></tr><tr><td>List(rolls/buns, pastry, soda)</td></tr><tr><td>List(whole milk)</td></tr><tr><td>List(curd cheese, coffee)</td></tr><tr><td>List(red/blush wine, newspapers)</td></tr><tr><td>List(sausage, whole milk, curd)</td></tr><tr><td>List(tr ...

# %%
fpGrowth = FPGrowth(itemsCol="itemsList", minSupport=0.03, minConfidence=0.03)
model1 = fpGrowth.fit(df4)

# %%
model1.freqItemsets.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>items</th><th>freq</th></tr></thead><tbody><tr><td>List(domestic eggs)</td><td>310</td></tr><tr><td>List(chicken)</td><td>421</td></tr><tr><td>List(citrus fruit)</td><td>806</td></tr><tr><td>List(berries)</td><td>298</td></tr><tr><td>List(frankfurter)</td><td>580</td></tr><tr><td>List(curd)</td><td>379</td></tr><tr><td>List(rolls/buns)</td><td>1245</td></tr><tr><td>List(root vegetables)</td><td>987</td></tr><tr><td>List(root vegetables, other vegetables)</td><td>333</td></tr><tr><td>List(root vegetables, whole milk)</td><td>297</td></tr><tr><td>List(pastry)</td><td>525</td></tr><tr><td>List(pork)</td><td>566</td></tr><tr><td>List(tropical fruit)</td><td>1015</td></tr><tr><td>List(hamburger meat)</td><td>322</td></tr><tr><td>List(sausage)</td><td>924</td></tr><tr><td>List(bottled beer)</td><td>474</td></tr><tr><td>List(coffee)</td><td>306</td></tr><tr><td>List(bottled water)</td><td>593</td></tr><tr><td>List(other vegetables)</td><td>1679</td></tr><tr><td>List(other vegetables, whole milk)</td><td>494</td></tr><tr><td>List(butter)</td><td>386</td></tr><tr><td>List(pip fruit)</td><td>727</td></tr><tr><td>List(whipped/sour cream)</td><td>408</td></tr><tr><td>List(shopping bags)</td><td>296</td></tr><tr><td>List(brown bread)</td><td>357</td></tr><tr><td>List(canned beer)</td><td>579</td></tr><tr><td>List(soda)</td><td>1017</td></tr><tr><td>List(beef)</td><td>515</td></tr><tr><td>List(newspapers)</td><td>306</td></tr><tr><td>List(yogurt)</td><td>983</td></tr><tr><td>List(whole milk)</td><td>2192</td></tr></tbody></table></div>

# %%
model1.associationRules.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>antecedent</th><th>consequent</th><th>confidence</th><th>lift</th><th>support</th></tr></thead><tbody><tr><td>List(other vegetables)</td><td>List(root vegetables)</td><td>0.1983323406789756</td><td>1.9762903450635512</td><td>0.03385866802236909</td></tr><tr><td>List(other vegetables)</td><td>List(whole milk)</td><td>0.2942227516378797</td><td>1.320109836842403</td><td>0.05022877478393493</td></tr><tr><td>List(root vegetables)</td><td>List(other vegetables)</td><td>0.3373860182370821</td><td>1.9762903450635512</td><td>0.03385866802236909</td></tr><tr><td>List(root vegetables)</td><td>List(whole milk)</td><td>0.3009118541033435</td><td>1.3501223015996273</td><td>0.03019827147941027</td></tr><tr><td>List(whole milk)</td><td>List(root vegetables)</td><td>0.135492700729927</td><td>1.3501223015996273</td><td>0.03019827147941027</td></tr><tr><td>List(whole milk)</td><td>List(other vegetables)</td><td>0.22536496350364962</td><td>1.3201098368424027</td><td>0.05022877478393493</td></tr></tbody></table></div>

# %%
model1.transform(df4).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>itemsList</th><th>prediction</th></tr></thead><tbody><tr><td>List(citrus fruit, semi-finished bread, margarine, ready soups)</td><td>List()</td></tr><tr><td>List(tropical fruit, yogurt, coffee)</td><td>List()</td></tr><tr><td>List(whole milk)</td><td>List(root vegetables, other vegetables)</td></tr><tr><td>List(pip fruit, yogurt, cream cheese, meat spreads)</td><td>List()</td></tr><tr><td>List(other vegetables, whole milk, condensed milk, long life bakery product)</td><td>List(root vegetables)</td></tr><tr><td>List(whole milk, butter, yogurt, rice)</td><td>List(root vegetables, other vegetables)</td></tr><tr><td>List(rolls/buns)</td><td>List()</td></tr><tr><td>List(other vegetables, UHT-milk, rolls/buns, bottled beer)</td><td>List(root vegetables, whole milk)</td></tr><tr><td>List(pot plants)</td><td>List()</td></tr><tr><td>List(whole milk, cereals)</td><td>List(root vegetables, other vegetables)</td></tr><tr><td>List(tropical fruit, other vegetables, white bread, bottled water)</td><td>List(root vegetables, whole milk)</td></tr><tr><td>List(citrus fruit, tropical fruit, whole milk, butter)</td><td>List(root vegetables, other vegetables)</td></tr><tr><td>List(beef)</td><td>List()</td></tr><tr><td>List(frankfurter, rolls/buns, soda)</td><td>List()</td></tr><tr><td>List(chicken, tropical fruit)</td><td>List()</td></tr><tr><td>List(butter, sugar, fruit/vegetable juice, newspapers)</td><td>List()</td></tr><tr><td>List(fruit/vegetable juice)</td><td>List()</td></tr><tr><td>List(packaged fruit/vegetables)</td><td>List()</td></tr><tr><td>List(chocolate)</td><td>List()</td></tr><tr><td>List(specialty bar)</td><td>List()</td></tr><tr><td>List(other vegetables)</td><td>List(root vegetables, whole milk)</td></tr><tr><td>List(butter milk, pastry)</td><td>List()</td></tr><tr><td>List(whole milk)</td><td>List(root vegetables, other vegetables)</td></tr><tr><td>List(tropical fruit, cream cheese, processed cheese, detergent)</td><td>List()</td></tr><tr><td>List(tropical fruit, root vegetables, other vegetables, frozen dessert)</td><td>List(whole milk)</td></tr><tr><td>List(bottled water, canned beer)</td><td>List()</td></tr><tr><td>List(yogurt)</td><td>List()</td></tr><tr><td>List(sausage, rolls/buns, soda, chocolate)</td><td>List()</td></tr><tr><td>List(other vegetables)</td><td>List(root vegetables, whole milk)</td></tr><tr><td>List(brown bread, soda, fruit/vegetable juice, canned beer)</td><td>List()</td></tr><tr><td>List(yogurt, beverages, bottled water, specialty bar)</td><td>List()</td></tr><tr><td>List(hamburger meat, other vegetables, rolls/buns, spices)</td><td>List(root vegetables, whole milk)</td></tr><tr><td>List(root vegetables, other vegetables, whole milk, beverages)</td><td>List()</td></tr><tr><td>List(pork, berries, other vegetables, whole milk)</td><td>List(root vegetables)</td></tr><tr><td>List(beef, grapes, detergent)</td><td>List()</td></tr><tr><td>List(pastry, soda)</td><td>List()</td></tr><tr><td>List(fruit/vegetable juice)</td><td>List()</td></tr><tr><td>List(canned beer)</td><td>List()</td></tr><tr><td>List(root vegetables, other vegetables, whole milk, dessert)</td><td>List()</td></tr><tr><td>List(citrus fruit, zwieback, newspapers)</td><td>List()</td></tr><tr><td>List(sausage, rolls/buns, soda, canned beer)</td><td>List()</td></tr><tr><td>List(tropical fruit, root vegetables, whole milk, yogurt)</td><td>List(other vegetables)</td></tr><tr><td>List(berries, yogurt)</td><td>List()</td></tr><tr><td>List(canned beer)</td><td>List()</td></tr><tr><td>List(butter milk, yogurt, cream cheese, spread cheese)</td><td>List()</td></tr><tr><td>List(coffee)</td><td>List()</td></tr><tr><td>List(pastry, bottled water)</td><td>List()</td></tr><tr><td>List(rolls/buns)</td><td>List()</td></tr><tr><td>List(misc. beverages)</td><td>List()</td></tr><tr><td>List(root vegetables, other vegetables, butter, curd)</td><td>List ...
